# %% [markdown]
# # Predicted Growth
# This notebook contains the following sections
# ### - Preparation
# ### - Preliminary Visualisation
# ### - Trend analysis with Linear Regression
# ### - Forcasting with Auto ARIMA

# %% [markdown]
# ### Preparation

# %%
# Importing Libraries for analysis

import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
import seaborn as sns
import statsmodels.api as sm
from statsmodels.tsa.arima.model import ARIMA
from pmdarima import auto_arima
warnings.filterwarnings("ignore", module="statsmodels")

# %%
# Read the CSV file to load the rental data from DATA VIC
data = pd.read_csv("../Data/Moving annual rent by suburb - March quarter 2023.csv", header=[0,1], index_col=0)

# Check data structure visually
data.head()
# Out:
#                                       Mar 2000 Unnamed: 2_level_0 Jun 2000  \
#                                          Count             Median    Count
# Albert Park-Middle Park-West St Kilda    1,143               $260    1,134
# Armadale                                   733               $200      737
# Carlton North                              864               $260      814
# Carlton-Parkville                        1,339               $260    1,304
# CBD-St Kilda Rd                          2,132               $320    2,264
#
#                                       Unnamed: 4_level_0 Sep 2000  \
#                                                   Median    Count
# Albert Park-Middle Park-West St Kilda               $260    1,177
# Armadale                                            $200      738
# Carlton North                                       $260      799
# Carlton-Parkville                                   $260    1,300
# CBD-St Kilda Rd                                     $320    2,358
#
#                                       Unnamed: 6_level_0 Dec 2000  \
#                                                   Median    Count
# Albert Park-Middle Park-West St Kilda               $270    1,178
# Armadale                                            $205      739
# Carlton North                                       $265      736
# Carlton-Parkville                                   $260    1,320
# CBD-St Kilda Rd                                     $320    2,361
#
#                                       Unnamed: 8_level_0 Mar 2001  \
#                                                   Median    Count
# Albert Park-Middle Park-West St Kilda               $275    1,208
# Armadale                                            $210      718
# Carlton North                                       $270      718
# Carlton-Parkville                                   $260    1,273
# CBD-St Kilda Rd                                     $320    2,591
#
#                                       Unnamed: 10_level_0  ... Mar 2022  \
#                                                    Median  ...    Count
# Albert Park-Middle Park-West St Kilda                $275  ...      867
# Armadale                                             $215  ...      805
# Carlton North                                        $270  ...      581
# Carlton-Parkville                                    $260  ...    6,143
# CBD-St Kilda Rd                                      $320  ...   17,845
#
#                                       Unnamed: 178_level_0 Jun 2022  \
#                                                     Median    Count
# Albert Park-Middle Park-West St Kilda                 $500      855
# Armadale                                              $430      851
# Carlton North                                         $580      535
# Carlton-Parkville                                     $310    6,018
# CBD-St Kilda Rd                                       $365   16,792
#
#                                       Unnamed: 180_level_0 Sep 2022  \
#                                                     Median    Count
# Albert Park-Middle Park-West St Kilda                 $515      881
# Armadale                                              $450      852
# Carlton North                                         $595      547
# Carlton-Parkville                                     $319    6,871
# CBD-St Kilda Rd                                       $390   18,284
#
#                                       Unnamed: 182_level_0 Dec 2022  \
#                                                     Median    Count
# Albert Park-Middle Park-West St Kilda                 $500      832
# Armadale                                              $450      840
# Carlton North                                         $600      546
# Carlton-Parkville                                     $340    6,627
# CBD-St Kilda Rd                                       $419   17,627
#
#                                       Unnamed: 184_level_0 Mar 2023  \
#                                                     Median    Count
# Albert Park-Middle Park-West St Kilda                 $525      786
# Armadale                                              $460      751
# Carlton North                                         $600      490
# Carlton-Parkville                                     $350    6,690
# CBD-St Kilda Rd                                       $450   17,426
#
#                                       Unnamed: 186_level_0
#                                                     Median
# Albert Park-Middle Park-West St Kilda                 $545
# Armadale                                              $490
# Carlton North                                         $620
# Carlton-Parkville                                     $400
# CBD-St Kilda Rd                                       $500
#
# [5 rows x 186 columns]

# %%
# Basic data cleaning
data.replace('-', np.nan, inplace=True)

# Convert to float for calculations in regression
for column in data.columns:
    if 'Median' in column[1]:
        data[column] = data[column].str.replace('$', '').astype(float)

# %%
# Create a list to hold the new column names
new_columns = []

# Iterate through the current columns
for col in data.columns:
    # If the column name contains "Unnamed", it's a median column
    if "Unnamed" in col[1]:
        # Extract the month and year from the previous column name in the new_columns list
        month_year = new_columns[-1].split(" ")[0]
        new_columns.append(f"{month_year} Median")
    else:
        # It's a count column, so just append "Count" to the column name
        new_columns.append(f"{col[0]} Count")

data.columns = new_columns

# Display the modified DataFrame
data.head()
# Out:
#                                       Mar 2000 Count  \
# Albert Park-Middle Park-West St Kilda          1,143
# Armadale                                         733
# Carlton North                                    864
# Carlton-Parkville                              1,339
# CBD-St Kilda Rd                                2,132
#
#                                        Unnamed: 2_level_0 Count  \
# Albert Park-Middle Park-West St Kilda                     260.0
# Armadale                                                  200.0
# Carlton North                                             260.0
# Carlton-Parkville                                         260.0
# CBD-St Kilda Rd                                           320.0
#
#                                       Jun 2000 Count  \
# Albert Park-Middle Park-West St Kilda          1,134
# Armadale                                         737
# Carlton North                                    814
# Carlton-Parkville                              1,304
# CBD-St Kilda Rd                                2,264
#
#                                        Unnamed: 4_level_0 Count  \
# Albert Park-Middle Park-West St Kilda                     260.0
# Armadale                                                  200.0
# Carlton North                                             260.0
# Carlton-Parkville                                         260.0
# CBD-St Kilda Rd                                           320.0
#
#                                       Sep 2000 Count  \
# Albert Park-Middle Park-West St Kilda          1,177
# Armadale                                         738
# Carlton North                                    799
# Carlton-Parkville                              1,300
# CBD-St Kilda Rd                                2,358
#
#                                        Unnamed: 6_level_0 Count  \
# Albert Park-Middle Park-West St Kilda                     270.0
# Armadale                                                  205.0
# Carlton North                                             265.0
# Carlton-Parkville                                         260.0
# CBD-St Kilda Rd                                           320.0
#
#                                       Dec 2000 Count  \
# Albert Park-Middle Park-West St Kilda          1,178
# Armadale                                         739
# Carlton North                                    736
# Carlton-Parkville                              1,320
# CBD-St Kilda Rd                                2,361
#
#                                        Unnamed: 8_level_0 Count  \
# Albert Park-Middle Park-West St Kilda                     275.0
# Armadale                                                  210.0
# Carlton North                                             270.0
# Carlton-Parkville                                         260.0
# CBD-St Kilda Rd                                           320.0
#
#                                       Mar 2001 Count  \
# Albert Park-Middle Park-West St Kilda          1,208
# Armadale                                         718
# Carlton North                                    718
# Carlton-Parkville                              1,273
# CBD-St Kilda Rd                                2,591
#
#                                        Unnamed: 10_level_0 Count  ...  \
# Albert Park-Middle Park-West St Kilda                      275.0  ...
# Armadale                                                   215.0  ...
# Carlton North                                              270.0  ...
# Carlton-Parkville                                          260.0  ...
# CBD-St Kilda Rd                                            320.0  ...
#
#                                       Mar 2022 Count  \
# Albert Park-Middle Park-West St Kilda            867
# Armadale                                         805
# Carlton North                                    581
# Carlton-Parkville                              6,143
# CBD-St Kilda Rd                               17,845
#
#                                        Unnamed: 178_level_0 Count  \
# Albert Park-Middle Park-West St Kilda                       500.0
# Armadale                                                    430.0
# Carlton North                                               580.0
# Carlton-Parkville                                           310.0
# CBD-St Kilda Rd                                             365.0
#
#                                       Jun 2022 Count  \
# Albert Park-Middle Park-West St Kilda            855
# Armadale                                         851
# Carlton North                                    535
# Carlton-Parkville                              6,018
# CBD-St Kilda Rd                               16,792
#
#                                        Unnamed: 180_level_0 Count  \
# Albert Park-Middle Park-West St Kilda                       515.0
# Armadale                                                    450.0
# Carlton North                                               595.0
# Carlton-Parkville                                           319.0
# CBD-St Kilda Rd                                             390.0
#
#                                       Sep 2022 Count  \
# Albert Park-Middle Park-West St Kilda            881
# Armadale                                         852
# Carlton North                                    547
# Carlton-Parkville                              6,871
# CBD-St Kilda Rd                               18,284
#
#                                        Unnamed: 182_level_0 Count  \
# Albert Park-Middle Park-West St Kilda                       500.0
# Armadale                                                    450.0
# Carlton North                                               600.0
# Carlton-Parkville                                           340.0
# CBD-St Kilda Rd                                             419.0
#
#                                       Dec 2022 Count  \
# Albert Park-Middle Park-West St Kilda            832
# Armadale                                         840
# Carlton North                                    546
# Carlton-Parkville                              6,627
# CBD-St Kilda Rd                               17,627
#
#                                        Unnamed: 184_level_0 Count  \
# Albert Park-Middle Park-West St Kilda                       525.0
# Armadale                                                    460.0
# Carlton North                                               600.0
# Carlton-Parkville                                           350.0
# CBD-St Kilda Rd                                             450.0
#
#                                       Mar 2023 Count  \
# Albert Park-Middle Park-West St Kilda            786
# Armadale                                         751
# Carlton North                                    490
# Carlton-Parkville                              6,690
# CBD-St Kilda Rd                               17,426
#
#                                        Unnamed: 186_level_0 Count
# Albert Park-Middle Park-West St Kilda                       545.0
# Armadale                                                    490.0
# Carlton North                                               620.0
# Carlton-Parkville                                           400.0
# CBD-St Kilda Rd                                             500.0
#
# [5 rows x 186 columns]

# %%
new_columns = []

for i, col in enumerate(data.columns):
    if "Unnamed" in col:
        month_year = new_columns[i-1].split(" ")[0] + " " + new_columns[i-1].split(" ")[1]
        new_columns.append(f"{month_year} Median")
    else:
        new_columns.append(col)

data.columns = new_columns

data.head()
# Out:
#                                       Mar 2000 Count  Mar 2000 Median  \
# Albert Park-Middle Park-West St Kilda          1,143            260.0
# Armadale                                         733            200.0
# Carlton North                                    864            260.0
# Carlton-Parkville                              1,339            260.0
# CBD-St Kilda Rd                                2,132            320.0
#
#                                       Jun 2000 Count  Jun 2000 Median  \
# Albert Park-Middle Park-West St Kilda          1,134            260.0
# Armadale                                         737            200.0
# Carlton North                                    814            260.0
# Carlton-Parkville                              1,304            260.0
# CBD-St Kilda Rd                                2,264            320.0
#
#                                       Sep 2000 Count  Sep 2000 Median  \
# Albert Park-Middle Park-West St Kilda          1,177            270.0
# Armadale                                         738            205.0
# Carlton North                                    799            265.0
# Carlton-Parkville                              1,300            260.0
# CBD-St Kilda Rd                                2,358            320.0
#
#                                       Dec 2000 Count  Dec 2000 Median  \
# Albert Park-Middle Park-West St Kilda          1,178            275.0
# Armadale                                         739            210.0
# Carlton North                                    736            270.0
# Carlton-Parkville                              1,320            260.0
# CBD-St Kilda Rd                                2,361            320.0
#
#                                       Mar 2001 Count  Mar 2001 Median  ...  \
# Albert Park-Middle Park-West St Kilda          1,208            275.0  ...
# Armadale                                         718            215.0  ...
# Carlton North                                    718            270.0  ...
# Carlton-Parkville                              1,273            260.0  ...
# CBD-St Kilda Rd                                2,591            320.0  ...
#
#                                       Mar 2022 Count  Mar 2022 Median  \
# Albert Park-Middle Park-West St Kilda            867            500.0
# Armadale                                         805            430.0
# Carlton North                                    581            580.0
# Carlton-Parkville                              6,143            310.0
# CBD-St Kilda Rd                               17,845            365.0
#
#                                       Jun 2022 Count  Jun 2022 Median  \
# Albert Park-Middle Park-West St Kilda            855            515.0
# Armadale                                         851            450.0
# Carlton North                                    535            595.0
# Carlton-Parkville                              6,018            319.0
# CBD-St Kilda Rd                               16,792            390.0
#
#                                       Sep 2022 Count  Sep 2022 Median  \
# Albert Park-Middle Park-West St Kilda            881            500.0
# Armadale                                         852            450.0
# Carlton North                                    547            600.0
# Carlton-Parkville                              6,871            340.0
# CBD-St Kilda Rd                               18,284            419.0
#
#                                       Dec 2022 Count  Dec 2022 Median  \
# Albert Park-Middle Park-West St Kilda            832            525.0
# Armadale                                         840            460.0
# Carlton North                                    546            600.0
# Carlton-Parkville                              6,627            350.0
# CBD-St Kilda Rd                               17,627            450.0
#
#                                       Mar 2023 Count  Mar 2023 Median
# Albert Park-Middle Park-West St Kilda            786            545.0
# Armadale                                         751            490.0
# Carlton North                                    490            620.0
# Carlton-Parkville                              6,690            400.0
# CBD-St Kilda Rd                               17,426            500.0
#
# [5 rows x 186 columns]

# %% [markdown]
# ### - Preliminary Visualisation

# %%
# Selecting a the first 5 suburbs for visualization
suburbs_to_plot = ['Albert Park-Middle Park-West St Kilda', 'Armadale', 'Carlton North', 'Carlton-Parkville', 'CBD-St Kilda Rd']

# Extracting the 'Median' columns
median_columns = [col for col in data.columns if 'Median' in col]

plt.figure(figsize=(10, 6))

for suburb in suburbs_to_plot:
    data.loc[suburb, median_columns].plot(label=suburb)

plt.legend(loc='upper left', bbox_to_anchor=(1,1), title='Suburb')
plt.title("Median Rental Prices Over last 20 years for sampled Suburbs")
plt.xlabel("Date")
plt.ylabel("Median rent")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Extracting the 'Median' columns
median_columns = [col for col in data.columns if 'Median' in col]

# Calculating the CAGR for each suburb
cagr = ((data[median_columns].iloc[:, -1] / data[median_columns].iloc[:, 0]) ** (1/(len(median_columns)/4)) - 1)

# Sorting the suburbs by CAGR in descending order and selecting the top 10
top_10_growth_suburbs = cagr.sort_values(ascending=False).head(5).index

plt.figure(figsize=(10, 6))

# Iterating through the top 10 suburbs to plot their median rental prices
for suburb in top_10_growth_suburbs:
    data.loc[suburb, median_columns].plot(label=suburb)

plt.legend(loc='upper left', bbox_to_anchor=(1,1), title='Suburb')
plt.title("Median Rental Prices Over last 20 years for Top 5 Growth Suburbs")
plt.xlabel("Date")
plt.ylabel("Median rent")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Identifying columns for the period 2015 to 2019
growth_period_columns = median_columns[-60:-12]

# Calculating the CAGR 
cagr_2015_to_2019 = ((data[growth_period_columns].iloc[:, -1] / data[growth_period_columns].iloc[:, 0]) ** (1/(len(growth_period_columns)/4)) - 1)

# Sorting the suburbs by CAGR and selecting the top 10
top_10_growth_suburbs_2015_to_2019 = cagr_2015_to_2019.sort_values(ascending=False).head(10).index

plt.figure(figsize=(10, 6))

# Iterating through the top 10 suburbs to plot their median rental prices over the entire 20-year period
for suburb in top_10_growth_suburbs_2015_to_2019:
    data.loc[suburb, median_columns].plot(label=suburb)

plt.legend(loc='upper left', bbox_to_anchor=(1,1), title='Suburb')
plt.title("Median Rental Prices Over last 20 years for Top 5 Growth Suburbs (2015 to 2019 Growth)")
plt.xlabel("Date")
plt.ylabel("Median Price")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# From the above visualisations we can see that suburbs with the highest predicted growth suffered least from the price drop during the pandemic. These areas are also located further out in rural regions of Victoria

# %% [markdown]
# ### Trend analysis with Linear Regression

# %%
# Separate the columns based on their names (So that it is simpler to perform Linear Regression)
count_columns = [col for col in data.columns if 'Count' in col]
median_columns = [col for col in data.columns if 'Median' in col]

# Create two new DataFrames
df_count = data[count_columns]
df_median = data[median_columns]

df_median
# Out:
#                                        Mar 2000 Median  Jun 2000 Median  \
# Albert Park-Middle Park-West St Kilda            260.0            260.0
# Armadale                                         200.0            200.0
# Carlton North                                    260.0            260.0
# Carlton-Parkville                                260.0            260.0
# CBD-St Kilda Rd                                  320.0            320.0
# ...                                                ...              ...
# Wanagaratta                                      125.0            125.0
# Warragul                                         130.0            135.0
# Warrnambool                                      130.0            135.0
# Wodonga                                          145.0            145.0
# Group Total                                      130.0            130.0
#
#                                        Sep 2000 Median  Dec 2000 Median  \
# Albert Park-Middle Park-West St Kilda            270.0            275.0
# Armadale                                         205.0            210.0
# Carlton North                                    265.0            270.0
# Carlton-Parkville                                260.0            260.0
# CBD-St Kilda Rd                                  320.0            320.0
# ...                                                ...              ...
# Wanagaratta                                      130.0            130.0
# Warragul                                         135.0            135.0
# Warrnambool                                      135.0            135.0
# Wodonga                                          150.0            150.0
# Group Total                                      130.0            130.0
#
#                                        Mar 2001 Median  Jun 2001 Median  \
# Albert Park-Middle Park-West St Kilda            275.0            280.0
# Armadale                                         215.0            220.0
# Carlton North                                    270.0            275.0
# Carlton-Parkville                                260.0            260.0
# CBD-St Kilda Rd                                  320.0            320.0
# ...                                                ...              ...
# Wanagaratta                                      130.0            130.0
# Warragul                                         135.0            135.0
# Warrnambool                                      140.0            140.0
# Wodonga                                          150.0            150.0
# Group Total                                      135.0            135.0
#
#                                        Sep 2001 Median  Dec 2001 Median  \
# Albert Park-Middle Park-West St Kilda            280.0            290.0
# Armadale                                         225.0            230.0
# Carlton North                                    280.0            280.0
# Carlton-Parkville                                265.0            270.0
# CBD-St Kilda Rd                                  320.0            320.0
# ...                                                ...              ...
# Wanagaratta                                      130.0            135.0
# Warragul                                         140.0            140.0
# Warrnambool                                      140.0            145.0
# Wodonga                                          150.0            150.0
# Group Total                                      135.0            135.0
#
#                                        Mar 2002 Median  Jun 2002 Median  ...  \
# Albert Park-Middle Park-West St Kilda            300.0            300.0  ...
# Armadale                                         233.0            230.0  ...
# Carlton North                                    290.0            290.0  ...
# Carlton-Parkville                                270.0            270.0  ...
# CBD-St Kilda Rd                                  320.0            320.0  ...
# ...                                                ...              ...  ...
# Wanagaratta                                      135.0            135.0  ...
# Warragul                                         150.0            150.0  ...
# Warrnambool                                      145.0            150.0  ...
# Wodonga                                          150.0            155.0  ...
# Group Total                                      140.0            140.0  ...
#
#                                        Dec 2020 Median  Mar 2021 Median  \
# Albert Park-Middle Park-West St Kilda            550.0            500.0
# Armadale                                         495.0            450.0
# Carlton North                                    590.0            580.0
# Carlton-Parkville                                395.0            350.0
# CBD-St Kilda Rd                                  420.0            380.0
# ...                                                ...              ...
# Wanagaratta                                      308.0            320.0
# Warragul                                         380.0            375.0
# Warrnambool                                      350.0            350.0
# Wodonga                                          330.0            340.0
# Group Total                                      320.0            330.0
#
#                                        Jun 2021 Median  Sep 2021 Median  \
# Albert Park-Middle Park-West St Kilda            500.0            500.0
# Armadale                                         440.0            425.0
# Carlton North                                    575.0            575.0
# Carlton-Parkville                                340.0            330.0
# CBD-St Kilda Rd                                  369.0            350.0
# ...                                                ...              ...
# Wanagaratta                                      330.0            350.0
# Warragul                                         380.0            390.0
# Warrnambool                                      360.0            370.0
# Wodonga                                          350.0            360.0
# Group Total                                      340.0            350.0
#
#                                        Dec 2021 Median  Mar 2022 Median  \
# Albert Park-Middle Park-West St Kilda            495.0            500.0
# Armadale                                         420.0            430.0
# Carlton North                                    580.0            580.0
# Carlton-Parkville                                320.0            310.0
# CBD-St Kilda Rd                                  350.0            365.0
# ...                                                ...              ...
# Wanagaratta                                      360.0            370.0
# Warragul                                         390.0            400.0
# Warrnambool                                      380.0            400.0
# Wodonga                                          370.0            380.0
# Group Total                                      350.0            360.0
#
#                                        Jun 2022 Median  Sep 2022 Median  \
# Albert Park-Middle Park-West St Kilda            515.0            500.0
# Armadale                                         450.0            450.0
# Carlton North                                    595.0            600.0
# Carlton-Parkville                                319.0            340.0
# CBD-St Kilda Rd                                  390.0            419.0
# ...                                                ...              ...
# Wanagaratta                                      380.0            380.0
# Warragul                                         400.0            420.0
# Warrnambool                                      400.0            420.0
# Wodonga                                          390.0            400.0
# Group Total                                      365.0            380.0
#
#                                        Dec 2022 Median  Mar 2023 Median
# Albert Park-Middle Park-West St Kilda            525.0            545.0
# Armadale                                         460.0            490.0
# Carlton North                                    600.0            620.0
# Carlton-Parkville                                350.0            400.0
# CBD-St Kilda Rd                                  450.0            500.0
# ...                                                ...              ...
# Wanagaratta                                      380.0            380.0
# Warragul                                         430.0            440.0
# Warrnambool                                      420.0            420.0
# Wodonga                                          410.0            410.0
# Group Total                                      380.0            390.0
#
# [159 rows x 95 columns]

# %%
# Checking if there are any missing values
total_missing_values = df_median.isnull().sum().sum()
print(total_missing_values)
# Out:
# 7

# %%
# Checking where the missing values are located
missing_rows = df_median[df_median.isnull().any(axis=1)]
missing_rows
# Out:
#            Mar 2000 Median  Jun 2000 Median  Sep 2000 Median  Dec 2000 Median  \
# Docklands              NaN            340.0              NaN              NaN
#
#            Mar 2001 Median  Jun 2001 Median  Sep 2001 Median  Dec 2001 Median  \
# Docklands              NaN              NaN              NaN              NaN
#
#            Mar 2002 Median  Jun 2002 Median  ...  Dec 2020 Median  \
# Docklands            320.0            340.0  ...            460.0
#
#            Mar 2021 Median  Jun 2021 Median  Sep 2021 Median  Dec 2021 Median  \
# Docklands            420.0            400.0            400.0            400.0
#
#            Mar 2022 Median  Jun 2022 Median  Sep 2022 Median  Dec 2022 Median  \
# Docklands            420.0            450.0            480.0            500.0
#
#            Mar 2023 Median
# Docklands            550.0
#
# [1 rows x 95 columns]

# %%
# Docklands had to be removed because there was no suitible way to impute conseccutive missing data
df_median = df_median.drop("Docklands")

# %%
df_median = df_median.astype('float64')

# %%
# There was a "Total" column that needed to be dropped
df_median = df_median.drop("Group Total")

# %%
# Convert the data from wide format to long format to fit them into Linear regression
df_long = df_median.stack().reset_index()
df_long.columns = ['Suburb', 'Date', 'Median']

# %%
# Assign a numeric value to each time period
date_columns = df_median.columns
date_to_time = {date: i for i, date in enumerate(date_columns)}
df_long['Time'] = df_long['Date'].map(date_to_time)

# %%
# Regression Analysis
# Dictionary to hold regression results
regression_results = {}
for suburb in df_long['Suburb'].unique():
    subset = df_long[df_long['Suburb'] == suburb]
    X = subset['Time'].values.reshape(-1, 1)
    y = subset['Median']
    
    X = sm.add_constant(X)  # adding a constant
    model = sm.OLS(y, X).fit()
    
    regression_results[suburb] = {
        'slope': model.params[1],
        'intercept': model.params[0],
        'r_squared': model.rsquared,
        'std_dev': np.std(subset['Median'])
    }

# Convert regression results to DataFrame for easier viewing
df_results = pd.DataFrame(regression_results).T

df_results
# Out:
#                                           slope   intercept  r_squared  \
# Albert Park-Middle Park-West St Kilda  3.528818  255.962987   0.913192
# Armadale                               3.300017  196.935009   0.927502
# Carlton North                          4.227207  238.903080   0.965069
# Carlton-Parkville                      1.589127  254.099773   0.725743
# CBD-St Kilda Rd                        1.990297  300.920410   0.642296
# ...                                         ...         ...        ...
# Traralgon                              2.517855  112.026976   0.961007
# Wanagaratta                            2.454631  104.774935   0.952250
# Warragul                               2.923131  111.896231   0.970688
# Warrnambool                            2.648297  128.500795   0.950450
# Wodonga                                2.468683  134.207454   0.971008
#
#                                           std_dev
# Albert Park-Middle Park-West St Kilda  100.707624
# Armadale                                93.448637
# Carlton North                          117.351462
# Carlton-Parkville                       50.872285
# CBD-St Kilda Rd                         67.727420
# ...                                           ...
# Traralgon                               70.045739
# Wanagaratta                             68.600103
# Warragul                                80.913829
# Warrnambool                             74.082610
# Wodonga                                 68.323190
#
# [145 rows x 4 columns]

# %%
# Suburbs with the highest slope (rate of growth)
top_slope_suburbs = df_results.nlargest(10, 'slope')

# Suburbs with the highest standard deviation (most variability)
top_std_dev_suburbs = df_results.nlargest(10, 'std_dev')

print("Top", 10, "suburbs with the highest rate of growth in rental prices:")
print(top_slope_suburbs[['slope']])

print("\nTop", 10, "suburbs with the most variability in rental prices:")
print(top_std_dev_suburbs[['std_dev']])
# Out:
# Top 10 suburbs with the highest rate of growth in rental prices:
#                                   slope
# Brighton East                  5.725535
# Brighton                       4.691836
# Torquay                        4.604892
# Mt Eliza-Mornington-Mt Martha  4.369703
# Carlton North                  4.227207
# Newport-Spotswood              4.096202
# Fitzroy North-Clifton Hill     4.059080
# Ocean Grove-Barwon Heads       3.956922
# Hampton-Beaumaris              3.936625
# Fitzroy                        3.926969
#
# Top 10 suburbs with the most variability in rental prices:
#                                   std_dev
# Brighton East                  159.143812
# Brighton                       133.439870
# Torquay                        126.417430
# Mt Eliza-Mornington-Mt Martha  120.530318
# Carlton North                  117.351462
# Fitzroy North-Clifton Hill     113.325030
# Newport-Spotswood              113.114591
# Fitzroy                        110.761362
# Ocean Grove-Barwon Heads       110.099037
# Hampton-Beaumaris              109.778084

# %% [markdown]
# The rental prices in these suburbs are not only increasing at a fast rate but are also experiencing significant fluctuations. This means that while there's a general upward trend, there are periods where the prices might dip or peak more than other suburbs. This could lead to potential instability if invested in.

# %% [markdown]
# From an investment point of view, these suburbs can be seen having both higher potential returns (due to the rapid growth) and higher risks (due to the high variability). Investors or renters looking for stability might be wary of such areas, while those willing to take on more risk for potentially higher returns might be attracted to them.

# %%
# Filter data from the last 5 years
last_5_years = df_long['Time'].max() - 20
df_last_5_years = df_long[df_long['Time'] > last_5_years]

# Regression Analysis for the last 5 years
regression_results_5_years = {}
for suburb in df_last_5_years['Suburb'].unique():
    subset = df_last_5_years[df_last_5_years['Suburb'] == suburb].dropna()
    
    if len(subset['Time'].unique()) > 1:
        X = subset['Time'].values.reshape(-1, 1)
        y = subset['Median']
        
        X = sm.add_constant(X)  # adding a constant
        model = sm.OLS(y, X).fit()
        
        regression_results_5_years[suburb] = {
            'slope': model.params[1],
            'intercept': model.params[0],
            'r_squared': model.rsquared,
            'std_dev': np.std(subset['Median'])
        }
    else:
        print(f"No variation in Time for {suburb}")

df_results_5_years = pd.DataFrame(regression_results_5_years).T

# Extract top suburbs based on slope and std_dev for the last 5 years
top_n = 10
top_slope_suburbs_5_years = df_results_5_years.nlargest(top_n, 'slope')
top_std_dev_suburbs_5_years = df_results_5_years.nlargest(top_n, 'std_dev')

print("Top", top_n, "suburbs with the highest rate of growth in rental prices in the last 5 years:")
print(top_slope_suburbs_5_years[['slope']])

print("\nTop", top_n, "suburbs with the most variability in rental prices in the last 5 years:")
print(top_std_dev_suburbs_5_years[['std_dev']])
# Out:
# Top 10 suburbs with the highest rate of growth in rental prices in the last 5 years:
#                                   slope
# Ocean Grove-Barwon Heads       8.939850
# Mt Eliza-Mornington-Mt Martha  8.347368
# Dromana-Portsea                8.345865
# Benalla                        7.620301
# Sale-Maffra                    7.477444
# Portland                       7.289474
# Torquay                        7.142857
# Warrnambool                    6.796992
# Hastings-Flinders              6.684211
# Wanagaratta                    6.645865
#
# Top 10 suburbs with the most variability in rental prices in the last 5 years:
#                                  std_dev
# Southbank                      62.696312
# CBD-St Kilda Rd                59.217312
# Ocean Grove-Barwon Heads       54.230987
# Dromana-Portsea                51.004902
# Mt Eliza-Mornington-Mt Martha  50.362784
# Benalla                        44.532993
# Sale-Maffra                    44.341713
# Torquay                        44.274711
# Carlton-Parkville              43.108555
# Portland                       42.669515

# %%
# Bar plots to present top 10 suburbs
fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(10, 12))

top_slope_suburbs_5_years['slope'].plot(kind='bar', ax=axes[0], color='skyblue')
axes[0].set_title('Top 10 Suburbs with Highest Rate of Growth in Rental Prices (Last 5 Years)')
axes[0].set_ylabel('Slope')

top_std_dev_suburbs_5_years['std_dev'].plot(kind='bar', ax=axes[1], color='lightcoral')
axes[1].set_title('Top 10 Suburbs with Most Variability in Rental Prices (Last 5 Years)')
axes[1].set_ylabel('Standard Deviation')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Forcasting with Auto ARIMA

# %%
# Converting columns to fate time format for arima analysis
df_median.columns = pd.to_datetime(df_median.columns.str.extract('(\w{3} \d{4})')[0], format='%b %Y')

# %%
# for the purpose of ranking by CAGR we need to store the three year prediction and growth rate
predicted_value_values = {}  
growth_rate_values = {}

for suburb in df_median.index:
    suburb_data = df_median.loc[suburb]

    # Auto ARIMA model fitted (Assumed no seasonal change, ignoring errors)
    stepwise_model = auto_arima(suburb_data, seasonal=False,
                                error_action="ignore", suppress_warnings=True, 
                                stepwise=True)

    # Predict the next 3 years 
    forecast = stepwise_model.predict(n_periods=12)

    # Get the last forecasted value
    last_forecasted_value = forecast.values[-1]
    
    # Get the last known value
    last_known_value = suburb_data[-1]
    
    # Calculate the growth rate with CAGR formula
    growth_rate = ((last_forecasted_value / last_known_value) ** (1/3)) - 1

    predicted_value_values[suburb] = last_forecasted_value  # Storing the predicted value
    growth_rate_values[suburb] = growth_rate

# Convert to a DataFrame for easier sorting and indexing
growth_df = pd.DataFrame(list(predicted_value_values.items()), columns=['Suburb', 'Predicted Value in 3 Years'])
growth_df['Growth Rate'] = growth_rate_values.values()

# Sort by the growth rate and take the top 10
top_10_growth_suburbs = growth_df.sort_values('Growth Rate', ascending=False).head(10)

# Display the top 10 suburbs with the highest growth rate, their predicted values, and growth rates
top_10_growth_suburbs
# Out:
#                    Suburb  Predicted Value in 3 Years  Growth Rate
# 132               Morwell                  435.840623     0.108475
# 137            Shepparton                  501.389902     0.096808
# 131        Moe-Newborough                  415.169686     0.090666
# 135           Sale-Maffra                  502.485838     0.079000
# 106     Hastings-Flinders                  616.932862     0.072563
# 125               Benalla                  484.920953     0.070758
# 118  Sebastopol-Delacombe                  478.157554     0.070292
# 142              Warragul                  534.060171     0.066709
# 134              Portland                  461.098612     0.066604
# 113                  Lara                  585.812573     0.064974

# %%
# Select the data for the last 5 years
last_5_years_data = df_median.loc[:, '2018-03-01':]

# Prepare a figure
plt.figure(figsize=(10, 6))

# Loop through each of the top 10 suburbs
for index, row in top_10_growth_suburbs.iterrows():
    suburb, forecasted_price = row['Suburb'], row['Predicted Value in 3 Years']
    
    # Get the past 5 yrs for this suburb
    suburb_data = last_5_years_data.loc[suburb]
    
    # time index for the forecasted price (3 years)
    forecast_index = pd.date_range(start=suburb_data.index[-1] + pd.DateOffset(months=3*12), periods=1, freq='Q')
    
    # Plot the historical data
    plt.plot(suburb_data.index, suburb_data, label=f'{suburb} - Historical')
    
    # Plot the forecasted price
    plt.plot(forecast_index, [forecasted_price], marker='o', linestyle='--', label=f'{suburb} - Forecast')

    plt.plot([suburb_data.index[-1], forecast_index[0]], [suburb_data[-1], forecasted_price], linestyle=':', color='grey')

plt.legend(loc='upper left', bbox_to_anchor=(1,1), title='Suburb')
plt.xlabel('Time')
plt.ylabel('Median Rental Price')
plt.title('Median Rental Price Over Last 5 Years with Forecast')
plt.show()

# %%
# Function to run the forcast on affordable suburbs
def compute_growth_and_predicted_rent(suburb_names):
    results = {}
    for suburb in suburb_names:
        suburb_data = df_median.loc[suburb]

        stepwise_model = auto_arima(suburb_data, seasonal=False,
                                    error_action="ignore", suppress_warnings=True,
                                    stepwise=True)

        forecast = stepwise_model.predict(n_periods=12)

    
        last_forecasted_value = forecast.values[-1]

        last_known_value = suburb_data[-1]

        growth_rate = ((last_forecasted_value / last_known_value) ** (1/3)) - 1

        # Store the results
        results[suburb] = {
            'Suburb': suburb,
            'Predicted Rent in 3 Years': last_forecasted_value,
            'Growth Rate': growth_rate
        }
    
    return pd.DataFrame(results).T  # Transpose to have suburbs as rows

# List of suburbs of interest
suburbs_of_interest = ['Caulfield', 'South Yarra', 'Fitzroy', 'Brunswick', 'Brighton']

# Get the growth rate and predicted rent for the suburbs of interest
growth_and_predicted_rent_df = compute_growth_and_predicted_rent(suburbs_of_interest)

# Display the results
growth_and_predicted_rent_df
# Out:
#                   Suburb Predicted Rent in 3 Years Growth Rate
# Caulfield      Caulfield                596.705422    0.064269
# South Yarra  South Yarra                 488.22921    0.005682
# Fitzroy          Fitzroy                633.404255    0.023944
# Brunswick      Brunswick                541.344963    0.037315
# Brighton        Brighton                779.255319    0.024347

# %%
# Select the data for the last 5 years
last_5_years_data = df_median.loc[:, '2018-03-01':]

# Prepare a figure
plt.figure(figsize=(10, 6))

# Loop through each of the 5 livable suburbs
for index, row in growth_and_predicted_rent_df.iterrows():
    suburb, forecasted_price = row['Suburb'], row['Predicted Rent in 3 Years']
    
    suburb_data = last_5_years_data.loc[suburb]
    
    forecast_index = pd.date_range(start=suburb_data.index[-1] + pd.DateOffset(months=3*12), periods=1, freq='Q')
    
    plt.plot(suburb_data.index, suburb_data, label=f'{suburb} - Historical')
    
    plt.plot(forecast_index, [forecasted_price], marker='o', linestyle='--', label=f'{suburb} - Forecast')

    plt.plot([suburb_data.index[-1], forecast_index[0]], [suburb_data[-1], forecasted_price], linestyle=':', color='grey')

# Add legend and labels
plt.legend(loc='upper left', bbox_to_anchor=(1,1), title='Suburb')
plt.xlabel('Time')
plt.ylabel('Median Rental Price')
plt.title('Median Rental Price Over Last 5 Years with Forecast (5 livable suburbs)')
plt.show()
