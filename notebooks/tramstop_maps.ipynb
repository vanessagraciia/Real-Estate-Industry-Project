# %%
# import library
import pandas as pd
import geopandas as gpd

# %%
# read the shape file
# sf stands for shape file
sf = gpd.read_file("../data/raw/PTV METRO TRAM STOP/PTV_METRO_TRAM_STOP.shp")

sf
# Out:
#      STOP_ID   LATITUDE                                   STOP_NAME  \
# 0      18730 -37.744359     134-Merribell Ave/Nicholson St (Coburg)
# 1      18732 -37.811375     44-Deepdene Park/Whitehorse Rd (Balwyn)
# 2      18733 -37.811750      45-Hardwicke St/Whitehorse Rd (Balwyn)
# 3      18734 -37.812242     46-Balwyn Cinema/Whitehorse Rd (Balwyn)
# 4      18735 -37.812919         47-Balwyn Rd/Whitehorse Rd (Balwyn)
# ...      ...        ...                                         ...
# 1660    6037 -37.767614              34-Bent St/High St (Northcote)
# 1661    6038 -37.769413         33-Arthurton Rd/High St (Northcote)
# 1662    6039 -37.771138          32-Mitchell St/High St (Northcote)
# 1663    6040 -37.774712  31-Northcote Town Hall/High St (Northcote)
# 1664    6041 -37.776690            30-Clarke St/High St (Northcote)
#
#        LONGITUDE TICKETZONE ROUTEUSSP                     geometry
# 0     144.977728          1         1  POINT (144.97773 -37.74436)
# ...

# %%
# Convert the geometry shaape to to latitude and longitude
# this code is taken from Applied Data Science workshop 
sf['geometry'] = sf['geometry'].to_crs("+proj=longlat +ellps=WGS84 +datum=WGS84 +no_defs")
sf.head()
# Out:
#   STOP_ID   LATITUDE                                STOP_NAME   LONGITUDE  \
# 0   18730 -37.744359  134-Merribell Ave/Nicholson St (Coburg)  144.977728
# 1   18732 -37.811375  44-Deepdene Park/Whitehorse Rd (Balwyn)  145.068671
# 2   18733 -37.811750   45-Hardwicke St/Whitehorse Rd (Balwyn)  145.071785
# 3   18734 -37.812242  46-Balwyn Cinema/Whitehorse Rd (Balwyn)  145.075930
# 4   18735 -37.812919      47-Balwyn Rd/Whitehorse Rd (Balwyn)  145.081524
#
#   TICKETZONE ROUTEUSSP                     geometry
# 0          1         1  POINT (144.97773 -37.74436)
# 1          1       109  POINT (145.06867 -37.81138)
# 2          1       109  POINT (145.07179 -37.81175)
# 3          1       109  POINT (145.07593 -37.81224)
# 4        1,2       109  POINT (145.08152 -37.81292)

# %%
csv_file_path = "../data/curated/tram_stop.csv"

# Convert the GeoDataFrame to CSV
sf.to_csv(csv_file_path, index=False)

# %%
# create a JSON 
geoJSON = sf[['STOP_ID', 'geometry']].drop_duplicates('STOP_ID').to_json()

# print the first 300 chars of the json
print(geoJSON[:300])
# Out:
# {"type": "FeatureCollection", "features": [{"id": "0", "type": "Feature", "properties": {"STOP_ID": "18730"}, "geometry": {"type": "Point", "coordinates": [144.97772797037925, -37.74435902693998]}}, {"id": "1", "type": "Feature", "properties": {"STOP_ID": "18732"}, "geometry": {"type": "Point", "coo

# %%
# create map for the tram stop
import folium
_map = folium.Map(location=[-37.8136, 144.9631], tiles="Stamen Terrain", zoom_start=10)

# refer to the folium documentations on how to plot aggregated data.
_map.add_child(folium.Choropleth(
    geo_data=geoJSON,
    name='choropleth',
))

_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
