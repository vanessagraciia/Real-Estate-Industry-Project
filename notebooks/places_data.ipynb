# %%
import requests
import pandas as pd

url = "https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/landmarks-and-places-of-interest-including-schools-theatres-health-services-spor/records?order_by=sub_theme"
limit = 100  # Maximum limit per request
offset = 0
all_records = []

while True:
    params = {"limit": limit, "offset": offset}
    response = requests.get(url, params=params)

    if response.status_code == 200:
        data = response.json()
        records = data['results']

        if not records:
            break  # No more records to fetchhs

        all_records.extend(records)
        offset += limit
    else:
        print("Request failed with status code:", response.status_code)
        break

# Create a DataFrame from all the records
df = pd.DataFrame(all_records)

# %%
df
# Out:
#                   theme                                        sub_theme  \
# 0             Transport                                  Railway Station
# 1             Mixed Use                            Retail/Office/Carpark
# 2    Leisure/Recreation  Informal Outdoor Facility (Park/Garden/Reserve)
# 3      Place of Worship                                           Church
# 4      Place of Worship                                           Church
# ..                  ...                                              ...
# 237    Education Centre         School - Primary and Secondary Education
# 238              Retail                                 Department Store
# 239              Retail                                 Department Store
# 240     Health Services                                 Medical Services
# 241           Mixed Use                            Retail/Office/Carpark
#
#                           feature_name  \
# 0    Flemington Bridge Railway Station
# ...

# %%
# Save the DataFrame to a CSV file
df.to_csv("../data/curated/melb_landmarks.csv", index=False)

print(f"Data saved to melbo_landmarks.csv with {len(all_records)} records.")
# Out:
# Data saved to melbo_landmarks.csv with 3157 records.

# %%
import requests
import pandas as pd

url = "https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/cafes-and-restaurants-with-seating-capacity/records?select=*&where=YEAR(census_year)%20%3D%202021&order_by=clue_small_area"
limit = 100  # Maximum limit per request
offset = 0
all_records = []

while True:
    params = {"limit": limit, "offset": offset}
    response = requests.get(url, params=params)

    if response.status_code == 200:
        data = response.json()
        records = data['results']
        if not records:
            break  # No more records to fetch

        all_records.extend(records)
        offset += limit
    else:
        print("Request failed with status code:", response.status_code)
        break

# Create a DataFrame from all the records
df2 = pd.DataFrame(all_records)
# Out:
# [{'census_year': '2021', 'block_id': 203, 'property_id': 103123, 'base_property_id': 103123, 'building_address': '258 Elgin Street CARLTON VIC 3053', 'clue_small_area': 'Carlton', 'business_address': '258 Elgin Street CARLTON VIC 3053', 'trading_name': 'Cafe Sua Da', 'industry_anzsic4_code': 4511, 'industry_anzsic4_description': 'Cafes and Restaurants', 'seating_type': 'Seats - Outdoor', 'number_of_seats': 6, 'longitude': 144.96553, 'latitude': -37.79671, 'location': {'lon': 144.96553, 'lat': -37.79671}}, {'census_year': '2021', 'block_id': 204, 'property_id': 109359, 'base_property_id': 109359, 'building_address': 'College Square on Swanston 768-804 Swanston Street CARLTON VIC 3053', 'clue_small_area': 'Carlton', 'business_address': '804 Swanston Street CARLTON VIC 3053', 'trading_name': 'The Longing Flavour', 'industry_anzsic4_code': 4511, 'industry_anzsic4_description': 'Cafes and Restaurants', 'seating_type': 'Seats - Indoor', 'number_of_seats': 50, 'longitude': 144.96517, 'latit
# ...

# %%
# Save the DataFrame to a CSV file
df2.to_csv("../data/curated/melb_resto.csv", index=False)

print(f"Data saved to melb_resto.csv with {len(all_records)} records.")
# Out:
# Data saved to melb_resto.csv with 3157 records.
